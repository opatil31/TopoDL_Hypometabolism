# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

from demographics import create_merged_table

# %%
PET_METADATA_PATH = 'adni-tables/All_Preprocessed_PET.csv'
MRI_PATH = 'adni-tables/All_Subjects_Structural_MRI_Images.csv'
DXSUM_NAME = 'adni-tables/All_Subjects_DXSUM.csv'
CDR_NAME = 'adni-tables/All_Subjects_CDR.csv'
# MRI_PATH = 'All_Subjects_Key_MRI.csv'

# %%
raw_df = pd.read_csv(MRI_PATH, parse_dates=['mri_date'])
raw_df
# Out:
#         image_id  subject_id  study_id mri_visit   mri_date  \
# 0          70846  037_S_1421     11613        sc 2007-08-27
# 1          70847  037_S_1421     11613        sc 2007-08-27
# 2          70848  037_S_1421     11613        sc 2007-08-27
# 3          70849  037_S_1421     11613        sc 2007-08-27
# 4          70850  037_S_1421     11613        sc 2007-08-27
# ...          ...         ...       ...       ...        ...
# 229371  11365077  035_S_7115    218809        sc 2022-11-15
# 229372  11365082  035_S_7115    218809        sc 2022-11-15
# 229373  11365090  082_S_7117    219059        sc 2022-11-03
# 229374  11365095  082_S_7117    219059        sc 2022-11-03
# 229375  11365107  082_S_7117    219059        sc 2022-11-03
#
#               mri_description mri_type mri_sequence  mri_thickness  mri_te  \
# 0       Head,3-P,2D,LOCALIZER       2D           RM            5.0     1.6
# 1       Head,3-P,2D,LOCALIZER       2D           RM            5.0     1.6
# 2       Head,3-P,2D,LOCALIZER       2D           RM            5.0     1.6
# 3       Head,3-P,2D,LOCALIZER       2D           RM            5.0     1.6
# 4       Head,3-P,2D,LOCALIZER       2D           RM            5.0     1.6
# ...                       ...      ...          ...            ...     ...
# 229371          T1 Brain Mask      NaN          NaN            NaN     NaN
# 229372   T1 MUSE segmentation      NaN          NaN            NaN     NaN
# 229373    Reoriented T1 Image      NaN          NaN            NaN     NaN
# 229374          T1 Brain Mask      NaN          NaN            NaN     NaN
# 229375   T1 MUSE segmentation      NaN          NaN            NaN     NaN
#
#         ...  mri_flip_angle  mri_acq_plane mri_width  mri_height mri_n_images  \
# 0       ...            30.0          Axial     256.0       256.0          5.0
# 1       ...            30.0        Coronal     256.0       256.0          5.0
# 2       ...            30.0       Sagittal     256.0       256.0          5.0
# 3       ...            30.0          Axial     256.0       256.0          5.0
# 4       ...            30.0        Coronal     256.0       256.0          5.0
# ...     ...             ...            ...       ...         ...          ...
# 229371  ...             NaN            NaN       NaN         NaN          NaN
# 229372  ...             NaN            NaN       NaN         NaN          NaN
# 229373  ...             NaN            NaN       NaN         NaN          NaN
# 229374  ...             NaN            NaN       NaN         NaN          NaN
# 229375  ...             NaN            NaN       NaN         NaN          NaN
#
#         mri_pixel_x  mri_pixel_y             mri_mfr  mri_mfr_model  \
# 0          1.015625     1.015625  GE MEDICAL SYSTEMS  GENESIS_SIGNA
# 1          1.015625     1.015625  GE MEDICAL SYSTEMS  GENESIS_SIGNA
# 2          1.015625     1.015625  GE MEDICAL SYSTEMS  GENESIS_SIGNA
# 3          1.015625     1.015625  GE MEDICAL SYSTEMS  GENESIS_SIGNA
# 4          1.015625     1.015625  GE MEDICAL SYSTEMS  GENESIS_SIGNA
# ...             ...          ...                 ...            ...
# 229371          NaN          NaN                 NaN            NaN
# 229372          NaN          NaN                 NaN            NaN
# 229373          NaN          NaN                 NaN            NaN
# 229374          NaN          NaN                 NaN            NaN
# 229375          NaN          NaN                 NaN            NaN
#
#         mri_field_str
# 0                 1.5
# 1                 1.5
# 2                 1.5
# 3                 1.5
# 4                 1.5
# ...               ...
# 229371            NaN
# 229372            NaN
# 229373            NaN
# 229374            NaN
# 229375            NaN
#
# [229376 rows x 23 columns]

# %%
def contains_any(desc, duplicate_types=None):
    if duplicate_types is None:
        duplicate_types = []
        return False
    if pd.isna(desc):
        return False
    return any([dup_type in desc for dup_type in duplicate_types])

# series_desc = [x for x in raw_df['series_description'].unique().tolist() if 'mprage' in str(x).lower() or 'mp-rage' in str(x).lower()]
duplicate_types = ['grappa2', 'repeat']

df = raw_df[
    (raw_df['mri_description'].str.contains('N3') 
     | raw_df['mri_description'].str.contains('B1') 
     | raw_df['mri_description'].str.contains('GradWarp') 
    ) &
    ~raw_df['mri_description'].str.lower().str.contains('calibration') &
    ~raw_df['mri_description'].str.lower().str.contains('mask') &
    
#             (raw_df['mri_description'].str.contains('MPRAGE') | raw_df['mri_description'].str.contains('MP-RAGE')) &
#             (~raw_df['series_description'].str.lower().apply(contains_any, duplicate_types=duplicate_types).fillna(False)) &
    (raw_df['mri_type'] == '3D')
#             (raw_df['mri_field_str'] == 3.0)
#             (raw_df['mri_acq_plane'] == 'Axial')
]

# df = raw_df[
#             (raw_df['series_type'] == 'T1w') &
# #             (raw_df['series_description'].str.contains('MPRAGE') | raw_df['series_description'].str.contains('MP-RAGE')) &
# #             (~raw_df['series_description'].str.lower().apply(contains_any, duplicate_types=duplicate_types).fillna(False)) &
# #             (raw_df['acquisition_type'] == '3D') &
# #             (raw_df['magnetic_field_strength'] == 3.0) &
#             (raw_df['acquisition_plane'] == 'Axial')
#            ]

# %%
df
# Out:
#         image_id  subject_id  study_id mri_visit   mri_date  \
# 119260     79928  037_S_1421     11613        sc 2007-08-27
# 119262     79947  037_S_1421     11613        sc 2007-08-27
# 119263     79948  037_S_1421     11613        sc 2007-08-27
# 119265     79950  037_S_1421     11613        sc 2007-08-27
# 119266     79951  037_S_1421     11613        sc 2007-08-27
# ...          ...         ...       ...       ...        ...
# 196647    882757  037_S_6046    113078        sc 2017-07-17
# 196648    882761  067_S_6045    113046        sc 2017-07-13
# 196649    882756  941_S_6052    113211        sc 2017-07-20
# 196650    882727  168_S_6051    113082        sc 2017-07-13
# 196651    882769  002_S_6053    113332        sc 2017-07-18
#
#                   mri_description mri_type mri_sequence  mri_thickness  \
# 119260              MPR; GradWarp       3D           RM            NaN
# 119262          MPR; GradWarp; N3       3D           RM            NaN
# 119263  MPR; GradWarp; N3; Scaled       3D           RM            NaN
# 119265        MPR-R; GradWarp; N3       3D           RM            NaN
# 119266            MPR-R; GradWarp       3D           RM            NaN
# ...                           ...      ...          ...            ...
# 196647                   MT1; N3m       3D        GR/IR            NaN
# 196648                   MT1; N3m       3D        GR/IR            NaN
# 196649                   MT1; N3m       3D        GR/IR            NaN
# 196650                   MT1; N3m       3D        GR/IR            NaN
# 196651                   MT1; N3m       3D        GR/IR            NaN
#
#         mri_te  ...  mri_flip_angle  mri_acq_plane mri_width  mri_height  \
# 119260    4.09  ...             8.0       Sagittal       NaN         NaN
# 119262    4.09  ...             8.0       Sagittal       NaN         NaN
# 119263    4.09  ...             8.0       Sagittal       NaN         NaN
# 119265    4.09  ...             8.0       Sagittal       NaN         NaN
# 119266    4.09  ...             8.0       Sagittal       NaN         NaN
# ...        ...  ...             ...            ...       ...         ...
# 196647    2.98  ...             9.0       Sagittal       NaN         NaN
# 196648    2.98  ...             9.0       Sagittal       NaN         NaN
# 196649    2.95  ...             9.0       Sagittal       NaN         NaN
# 196650    2.98  ...             9.0       Sagittal       NaN         NaN
# 196651    2.98  ...             9.0       Sagittal       NaN         NaN
#
#        mri_n_images  mri_pixel_x  mri_pixel_y             mri_mfr  \
# 119260          NaN          NaN          NaN  GE MEDICAL SYSTEMS
# 119262          NaN          NaN          NaN  GE MEDICAL SYSTEMS
# 119263          NaN          NaN          NaN  GE MEDICAL SYSTEMS
# 119265          NaN          NaN          NaN  GE MEDICAL SYSTEMS
# 119266          NaN          NaN          NaN  GE MEDICAL SYSTEMS
# ...             ...          ...          ...                 ...
# 196647          NaN          NaN          NaN             SIEMENS
# 196648          NaN          NaN          NaN             SIEMENS
# 196649          NaN          NaN          NaN             SIEMENS
# 196650          NaN          NaN          NaN             SIEMENS
# 196651          NaN          NaN          NaN             SIEMENS
#
#         mri_mfr_model  mri_field_str
# 119260  GENESIS_SIGNA            1.5
# 119262  GENESIS_SIGNA            1.5
# 119263  GENESIS_SIGNA            1.5
# 119265  GENESIS_SIGNA            1.5
# 119266  GENESIS_SIGNA            1.5
# ...               ...            ...
# 196647         Prisma            3.0
# 196648     Prisma_fit            3.0
# 196649     Prisma_fit            3.0
# 196650     Prisma_fit            3.0
# 196651     Prisma_fit            3.0
#
# [36553 rows x 23 columns]

# %%
df['mri_description'].value_counts()
# Out:
# mri_description
# MT1; GradWarp; N3m                              7578
# MPR; GradWarp                                   3846
# MPR-R; GradWarp                                 3757
# MPR; GradWarp; B1 Correction; N3                3182
# MPR; GradWarp; B1 Correction                    3181
# MPR-R; GradWarp; B1 Correction; N3              3090
# MPR-R; GradWarp; B1 Correction                  3090
# MT1; N3m                                        2898
# MPR; GradWarp; B1 Correction; N3; Scaled        2495
# MPR-R; GradWarp; N3                              678
# MPR; GradWarp; N3                                673
# MPR-R; GradWarp; B1 Correction; N3; Scaled       616
# MPR; GradWarp; N3; Scaled                        506
# MPR; GradWarp; B1 Correction; N3; Scaled_2       253
# MPR; ; N3                                        156
# MPR-R; GradWarp; N3; Scaled                      151
# MPR; ; N3; Scaled                                106
# MPR-R; ; N3                                       84
# MPR-R; GradWarp; B1 Correction; N3; Scaled_2      82
# MPR; GradWarp; N3; Scaled_2                       59
# MPR; ; N3; Scaled_2                               29
# MPR-R; GradWarp; N3; Scaled_2                     20
# MPR-R; ; N3; Scaled                               15
# MPR-R; ; N3; Scaled_2                              8
# Name: count, dtype: int64

# %%
pet_meta = pd.read_csv(PET_METADATA_PATH, parse_dates=['image_date'])
df2 = create_merged_table(pet_meta, df, 'subject_id', 'subject_id', 'image_date', 'mri_date', suffixes=('_pet', '_mri'))
df2 = df2.rename(columns={'subject_id_pet': 'subject_id'}).dropna(subset=['image_id_mri']).astype({'image_id_mri': int})

cols = ['subject_id', 'image_id_pet', 'image_id_mri', 'image_date', 'mri_date', 'mri_acq_plane', 'mri_field_str', 'mri_description']
df2 = df2[cols]

# %%
df2
# Out:
#       subject_id  image_id_pet  image_id_mri image_date   mri_date  \
# 0     037_S_1421         71920         79928 2007-09-04 2007-08-27
# 1     037_S_1421         91372         94524 2008-02-20 2008-02-20
# 2     037_S_1421        118139        121636 2008-09-17 2008-09-17
# 3     037_S_1421        144086        149806 2009-05-13 2009-05-13
# 4     037_S_1421        194588        203709 2010-09-24 2010-09-24
# ...          ...           ...           ...        ...        ...
# 3482  053_S_5296        403696        416077 2013-12-19 2013-12-10
# 3491  027_S_6034        916043        882765 2017-09-25 2017-07-06
# 3492  141_S_6041        894660        882763 2017-08-21 2017-07-06
# 3493  941_S_6052        882052        882756 2017-07-24 2017-07-20
# 3494  168_S_6051        918915        882727 2017-08-02 2017-07-13
#
#      mri_acq_plane  mri_field_str     mri_description
# 0         Sagittal            1.5       MPR; GradWarp
# 1         Sagittal            1.5   MPR; GradWarp; N3
# 2         Sagittal            1.5   MPR; GradWarp; N3
# 3         Sagittal            1.5   MPR; GradWarp; N3
# 4         Sagittal            1.5   MPR; GradWarp; N3
# ...            ...            ...                 ...
# 3482      Sagittal            3.0            MT1; N3m
# 3491      Sagittal            3.0            MT1; N3m
# 3492      Sagittal            3.0  MT1; GradWarp; N3m
# 3493      Sagittal            3.0            MT1; N3m
# 3494      Sagittal            3.0            MT1; N3m
#
# [3393 rows x 8 columns]

# %%
dxsum = pd.read_csv(DXSUM_NAME, parse_dates=['EXAMDATE'])
cdr = pd.read_csv(CDR_NAME, parse_dates=['VISDATE'])

df3 = create_merged_table(df2, dxsum, 'subject_id', 'PTID', 'image_date', 'EXAMDATE')
cols = cols + ['DIAGNOSIS']
df3 = df3[cols]

# %%
data = create_merged_table(df3, cdr, 'subject_id', 'PTID', 'image_date', 'VISDATE')
cols = cols + ['CDRSB']
data = data[cols]

# %%
data

# %%
data[data['DIAGNOSIS'] == 3.0]

# %%
count = 0
for subj_id in data['subject_id'].unique():
    subj_data = data[data['subject_id'] == subj_id]
    mri_types = subj_data['mri_description']
    if mri_types.str.lower().str.contains('mask').any():
#         display(subj_data)
        count += 1
count

# %%
data['mri_description'].value_counts()

# %%
def write_img_ids(data, date_limit=None):
    '''
    Write the image IDs to a text file separated by commas. Makes it easier to copy-paste the IDs into ADNI ARC builder 
    to download the images.
    '''
    cohorts = data[data['image_date'] < date_limit] if date_limit is not None else data
    
    cn_cohort = cohorts[cohorts['DIAGNOSIS'] == 1.0]['image_id_mri']
    mci_cohort = cohorts[cohorts['DIAGNOSIS'] == 2.0]['image_id_mri']
    ad_cohort = cohorts[cohorts['DIAGNOSIS'] == 3.0]['image_id_mri']
    
    print(f'CN: {len(cn_cohort.unique())}')
    print(f'MCI: {len(mci_cohort.unique())}')
    print(f'AD: {len(ad_cohort.unique())}')
    

    with open('cn_mri_cohort.txt', 'w') as f:
        f.write(','.join(cn_cohort.astype(str)))
        
    with open('mci_mri_cohort.txt', 'w') as f:
        f.write(','.join(mci_cohort.astype(str)))
        
    with open('ad_mri_cohort.txt', 'w') as f:
        f.write(','.join(ad_cohort.astype(str)))
        
        
def write_all_cohorts(data, date_limit=None):
    '''
    Write the fully merged data table to a CSV file. Limit by a maximum date
    '''
    all_cohorts_fname = 'all_cohorts_mri.csv'
    if date_limit is not None:
        data = data[data['image_date'] < date_limit]
        
    data.to_csv(all_cohorts_fname)

# %%
# write_img_ids(data)

# %%
# write_all_cohorts(data)

# %%
104116,104161

# %%
data[data['image_id_pet'] == 155693]
