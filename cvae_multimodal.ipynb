# %%
import pandas as pd

# %%
all_cohorts_path = '/home/hice1/khom9/CS8903/adni-tables/all_cohorts_pet_mri.csv'

# %%
all_cohorts = pd.read_csv(all_cohorts_path, index_col=0)

# %%
all_cohorts['image_id_pet'].unique().shape
# Out:
# (3393,)

# %%
all_cohorts['image_id_mri'].unique().shape
# Out:
# (3227,)
